# %% [markdown]
# <a href="https://colab.research.google.com/github/LeCanardNoir/AlgoPractices/blob/main/Astar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pygame
import numpy as np


class Cell:
  def __init__(self, width, height, rowPos, colPos):
    self.width = width
    self.height = height

class Board:
  def __init__(self, width, height, cellGap, nRow, nCol):
    self.width = width
    self.height = height
    self.cellGap = cellGap
    self.nRow = nRow
    self.nCol = nCol
    self.cells = np.darray()
    print(self.cells)

test = Board(800, 800, 2, 10, 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#
# TypeError: order must be str, not int
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-eddd2eb6e964> in <cell line: 0>()
#      18     print(self.cells)
#      19
# ---> 20 test = Board(800, 800, 2, 10, 10)
#
# <ipython-input-9-eddd2eb6e964> in __init__(self, width, height, cellGap, nRow, nCol)
#      15     self.nRow = nRow
#      16     self.nCol = nCol
# ---> 17     self.cells = np.reshape(np.array([], dtype=Cell), nRow, nCol)
#      18     print(self.cells)
#      19
#
# ...
